# %%
import folium
import pandas as pd

# %%
pakistan_map = folium.Map(location = [31.17,72.7],zoom_start=6.5,tiles='OpenStreetMap')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/files/covid_data.csv')
df
# Out:
#                City  Latitude  Longitude  Total_Cases  Recoveries  Deaths
# 0            Attock   33.7660    72.3609         1637        1504      35
# 1      Bahawalnagar   30.0025    73.2412         2279        2139      29
# 2        Bahawalpur   29.3544    71.6911        10021        9630     268
# 3           Bhakkar   31.6082    71.0854         2782        2604      52
# 4           Chakwal   32.9328    72.8630         1869        1754       5
# 5           Chiniot   31.7292    72.9822         2724        2554      71
# 6   Dera Ghazi Khan   30.0489    70.6455         5138        4829     204
# 7         Faislabad   31.4504    73.1350        26257       24739    1274
# 8        Gujranwala   32.1877    74.1945        10238        9504     611
# 9            Gujrat   32.5731    74.1005         7978        7769     115
# 10        Hafizabad   32.0712    73.6895         2374        2254      25
# 11            Jhang   31.2781    72.3317         3739        3690      26
# 12           Jhelum   32.9425    73.7257         2855        2689      58
# 13            Kasur   31.1179    74.4408         2969        2839      18
# 14         Khanewal   30.2864    71.9320         2873        2749       7
# 15          Khushab   32.2955    72.3489         2581        2439      78
# 16           Lahore   31.5204    74.3587       222246      214325    5076
# 17           Layyah   30.9693    70.9428         2189        2054      17
# 18          Lodhran   29.5467    71.6276         1805        1654      33
# 19  Mandi Bahauddin   32.5742    73.4828         2371        2239      22
# 20         Mianwali   32.5839    71.5370         2999        2719     137
# 21           Multan   30.1575    71.5249        22313       21199     897
# 22     Muzaffargarh   30.0736    71.1805         3049        2504     394
# 23    Nankana Sahib   31.4492    73.7125         2855        2704      23
# 24          Narowal   32.1014    74.8800         1099        1054       3
# 25            Okara   30.8138    73.4534         4000        3839      41
# 26        Pakpattan   30.3573    73.3827         2496        2304      22
# 27         Rajanpur   29.1044    70.3301         1467        1324       7
# 28       Rawalpindi   33.5651    73.0169        38527       36313    2046
# 29   Rahim Yar Khan   28.4212    70.2989         8094        7729     290
# 30          Sahiwal   30.6682    73.1114         4395        4139     107
# 31         Sargodha   32.0740    72.6861        11052       10539     364
# 32      Sheikhupura   31.7167    73.9850         4915        4594     171
# 33          Sialkot   32.4945    74.5229         8742        8354     247
# 34   Toba Tek Singh   30.9709    72.4826         4369        4085     137
# 35           Vehari   30.0442    72.3441         3201        3071      16

# %%
t = 0
for c in df['Total_Cases']:
  t = int(c)+int(t)

# %%
for city,lat,lon,tc,re,de in zip(list(df['City']),list(df['Latitude']),list(df['Longitude']),list(df['Total_Cases']),list(df['Recoveries']),list(df['Deaths'])):
    folium.CircleMarker(location = [lat,lon],
                       radius = (tc/t)*100,
                       color = 'black',
                       fill = True,
                       fill_color = 'blue').add_to(pakistan_map)
    abc = '<strong>City:  ' + city + '</strong> <br>' + 'Total Cases: ' + str(tc) + '<br>'+ 'Recoveries: ' + str(re) + '<br>'+ 'Deaths: '+ str(de)
    iframe = folium.IFrame(abc, width=200, height=80)
    popupData = folium.Popup(iframe, max_width=300)
    folium.Marker(location = [lat,lon], popup=popupData).add_to(pakistan_map)
    

pakistan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36d89f097e947215ecdcc6a5f42b2164 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36d89f097e947215ecdcc6a5f42b2164&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_36d89f097e947215ecdcc6a5f42b2164 = L.map(
#                 &quot;map_36d89f097e947215ecdcc6a5f42b2164&quot;,
#                 {
#                     center: [31.17, 72.7],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ac033a7fa26e434cae19851f5df94c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#             var circle_marker_b10743b0d0ffc0dc5ef2210255bf3f2c = L.circleMarker(
#                 [33.766, 72.3609],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.37162484279156777, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#             var marker_55cf74a7ef05c40a430e42c4f845fb17 = L.marker(
#                 [33.766, 72.3609],
#                 {}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#         var popup_be5850ca28aac91f9f765d3f34ec404c = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_11ae81045e6a3825647803b7978b9d25 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBBdHRvY2s8L3N0cm9uZz4gPGJyPlRvdGFsIENhc2VzOiAxNjM3PGJyPlJlY292ZXJpZXM6IDE1MDQ8YnI+RGVhdGhzOiAzNQ==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_be5850ca28aac91f9f765d3f34ec404c.setContent(i_frame_11ae81045e6a3825647803b7978b9d25);
#
#
#         marker_55cf74a7ef05c40a430e42c4f845fb17.bindPopup(popup_be5850ca28aac91f9f765d3f34ec404c)
#         ;
#
#
#
#
#             var circle_marker_17b60f921675ddb140ed2b11e308d30a = L.circleMarker(
#                 [30.0025, 73.2412],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.5173689778387189, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#             var marker_524cf1478dd060002474aab322f1ecf6 = L.marker(
#                 [30.0025, 73.2412],
#                 {}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#         var popup_6b48d405ec42c158100b504eea8a0eb0 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_9967017dc13f32c7fc71b034f50b151e = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBCYWhhd2FsbmFnYXI8L3N0cm9uZz4gPGJyPlRvdGFsIENhc2VzOiAyMjc5PGJyPlJlY292ZXJpZXM6IDIxMzk8YnI+RGVhdGhzOiAyOQ==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;80&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_6b48d405ec42c158100b504eea8a0eb0.setContent(i_frame_9967017dc13f32c7fc71b034f50b151e);
#
#
#         marker_524cf1478dd060002474aab322f1ecf6.bindPopup(popup_6b48d405ec42c158100b504eea8a0eb0)
#         ;
#
#
#
#
#             var circle_marker_92d3d7fba011dad18c6d0509ac670d5a = L.circleMarker(
#                 [29.3544, 71.6911],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.27492519829829, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#             var marker_9cfa9e5fdba5f056e10609a9943c2cd5 = L.marker(
#                 [29.3544, 71.6911],
#                 {}
#             ).addTo(map_36d89f097e947215ecdcc6a5f42b2164);
#
#
#         var popup_4e7289e8447c7a97238d14f909feb8ca = L.popup({&quot;maxWidth&quot;: 300});
#
#
#             var i_frame_555396dd7d45fee68ef1c93d00d280d3 = $(`&lt;iframe src=&quot;data:text/ht
